# %%
import pandas

# %%
df = pandas.read_csv("nominal.csv")

# %%
df[df.Dalc == 5]
# Out:
#      Unnamed: 0 sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 29           29   M   16       U     GT3       T     4     4   teacher
# 61           61   F   16       U     GT3       T     1     1  services
# 66           66   M   15       U     GT3       A     4     4     other
# 100         100   M   16       U     GT3       T     4     4  services
# 223         223   M   18       U     GT3       T     2     2     other
# 236         236   M   17       U     LE3       T     2     2     other
# 247         247   M   22       U     GT3       T     3     1  services
# 327         327   M   17       R     GT3       T     2     2  services
# 349         349   M   18       R     GT3       T     3     2     other
# 424          29   M   16       U     GT3       T     4     4   teacher
# 456          61   F   16       U     GT3       T     1     1  services
# 461          66   M   15       U     GT3       A     4     4     other
# ...

# %%
import matplotlib.pyplot as plt

# %%
age_metrics = df.groupby('age').mean()
age_metrics
# Out:
#      Unnamed: 0      Medu      Fedu  traveltime  studytime  failures  \
# age
# 15   130.087629  2.871134  2.608247    1.453608   2.072165  0.134021
# 16   215.857651  2.629893  2.444840    1.508897   1.871886  0.160142
# 17   327.032491  2.534296  2.321300    1.519856   1.942238  0.227437
# 18   382.351351  2.572072  2.373874    1.603604   2.063063  0.288288
# 19   381.303571  2.089286  1.928571    1.535714   1.946429  1.000000
# 20   404.111111  2.222222  1.555556    1.666667   1.777778  1.000000
# 21   404.000000  2.000000  2.000000    1.333333   2.000000  2.333333
# 22   263.000000  3.000000  1.000000    1.000000   1.000000  3.000000
#
#        famrel  freetime     goout      Dalc      Walc    health   absences  \
# age
# 15   4.000000  3.268041  2.804124  1.371134  1.963918  3.525773   3.097938
# 16   3.839858  3.170819  3.174377  1.409253  2.249110  3.601423   3.882562
# 17   3.981949  3.212996  3.241877  1.541516  2.476534  3.610108   4.924188
# ...

# %%
age_metrics.plot.bar(y = 'Dalc')
age_metrics.plot.bar(y = 'Walc')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
walc_metrics = df.groupby('Walc').mean()
dalc_metrics = df.groupby('Dalc').mean()

# %%
dalc_metrics.plot.bar(y = 'age')
walc_metrics.plot.bar(y = 'age')
# Out:
# <AxesSubplot:xlabel='Walc'>
