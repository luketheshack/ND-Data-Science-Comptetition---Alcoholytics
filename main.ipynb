# %%
import pandas

# %%
df = pandas.read_csv("nominal.csv")

# %%
df[df.Dalc == 5]
# Out:
#      Unnamed: 0  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  \
# 29           29    1   16        0        1        1     4     4     4     4
# 61           61    0   16        0        1        1     1     1     3     3
# 66           66    1   15        0        1        0     4     4     2     3
# 100         100    1   16        0        1        1     4     4     3     3
# 223         223    1   18        0        1        1     2     2     2     2
# 236         236    1   17        0        0        1     2     2     2     2
# 247         247    1   22        0        1        1     3     1     3     3
# 327         327    1   17        1        1        1     2     2     3     2
# 349         349    1   18        1        1        1     3     2     2     2
# 424          29    1   16        0        1        1     4     4     4     4
# 456          61    0   16        0        1        1     1     1     3     3
# 461          66    1   15        0        1        0     4     4     2     3
# 495         100    1   16        0        1        1     4     4     3     3
# 538         143    0   18        0        1        0     3     2     2     3
# 632         237    1   18        0        1        1     2     2     2     2
# 645         250    1   17        0        0        1     2     2     2     2
# 674         279    1   22        0        1        1     3     1     3     3
# 774         379    1   17        1        1        1     2     2     3     2
# 808         413    1   21        1        0        1     1     1     0     2
# 842         447    1   17        1        1        1     2     1     2     2
# 852         457    1   17        1        0        1     1     2     0     3
# 895         500    1   17        0        1        1     1     2     2     2
# 918         523    1   18        0        0        1     4     4     0     1
# 925         530    1   17        0        1        1     3     3     3     3
# 971         576    1   18        1        1        1     3     2     2     2
# 993         598    1   18        0        0        1     1     2     0     3
#
#      ...  famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 29   ...       4         4      5     5     5       4        16  10  12  11
# 61   ...       5         5      5     5     5       4         6  10   8  11
# 66   ...       1         3      3     5     5       2         4  13  13  12
# 100  ...       4         5      5     5     5       3        14   7   7   5
# 223  ...       3         3      3     5     5       3         0  12  13  13
# 236  ...       4         4      2     5     5       3         4  14  13  13
# 247  ...       5         4      5     5     5       0        16   6   8   8
# 327  ...       4         4      5     5     5       3         8  11  10  10
# 349  ...       2         5      5     5     5       4        10  11  13  13
# 424  ...       4         4      5     5     5       4         4  12  11  12
# 456  ...       5         5      5     5     5       4         0  10  10  16
# 461  ...       1         3      3     5     5       2         0  11  12  12
# 495  ...       4         5      5     5     5       3        12   9   9   8
# 538  ...       4         3      3     5     1       4        10  12  11  11
# 632  ...       3         3      3     5     5       3         9  10   9  10
# 645  ...       4         4      2     5     5       3         0  16  16  16
# 674  ...       5         4      5     5     5       0        12   7   8   5
# 774  ...       4         4      5     5     5       3         2  11  10  10
# 808  ...       5         3      3     5     2       3        21   9  10  10
# 842  ...       5         5      5     5     5       2         8   8  10   9
# 852  ...       5         5      5     5     5       2         4  10  11  11
# 895  ...       5         3      5     5     5       0        12   6   7   7
# 918  ...       5         5      5     5     5       4         2   5   6   6
# 925  ...       4         1      4     5     5       2         8   7  10   9
# 971  ...       2         5      5     5     5       4         8   9  10  11
# 993  ...       4         1      4     5     5       0         8  10  11  11
#
# [26 rows x 33 columns]

# %%
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu',
#        'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
ages = df["age"].value_counts()

# %%
age_x = []
age_y = []

x = 0
y = 0

for i in ages.items():
    x, y = i
    age_data.append([x, y])

plt.bar([1, 2, 3], [4, 5,6])
plt.show()

# %%
age_metrics = df.groupby('age').mean()

# %%
age_metrics.plot.bar(y = 'Dalc')
age_metrics.plot.bar(y = 'Walc')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
walc_metrics = df.groupby('Walc').mean()
dalc_metrics = df.groupby('Dalc').mean()

# %%
dalc_metrics.plot.bar(y = 'age')
walc_metrics.plot.bar(y = 'age')
# Out:
# <AxesSubplot:xlabel='Walc'>

# %%
age_metrics.plot.bar(y = 'absences')
age_metrics.plot.bar(y = 'absences')
# Out:
# <AxesSubplot:xlabel='age'>
